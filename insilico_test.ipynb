# sample_1259  6.406250  6.742188  6.980469
# sample_1260  7.757812  8.109375  8.468750
# sample_1261  5.039062  5.105469  5.148438
# sample_1262  8.617188  9.296875  9.859375
# sample_1263  4.765625  4.949219  5.078125
# sample_1264  6.886719  7.097656  7.378906
# sample_1265  4.785156  5.074219  5.101562
# sample_1266  4.683594  4.777344  4.906250
# sample_1267  6.328125  6.578125  6.812500
# sample_1268  6.441406  6.800781  6.792969
# sample_1269  6.675781  7.089844  7.277344
# sample_1270  4.792969  4.550781  4.238281
# sample_1271  7.042969  7.414062  7.765625
# sample_1272  6.179688  6.523438  6.769531
# sample_1273  6.609375  7.050781  7.445312
# sample_1274  5.304688  5.425781  5.566406
# sample_1275  1.098633  0.000000  0.000000
# sample_1276  5.531250  5.667969  6.003906
# sample_1277  4.187500  4.316406  4.429688
# sample_1278  6.222656  6.457031  6.714844
# sample_1279  6.652344  7.066406  7.402344
# sample_1280  4.382812  4.441406  4.476562
# sample_1281  6.281250  6.625000  6.906250
# sample_1282  6.457031  6.875000  6.937500
# sample_1283  7.289062  7.656250  8.062500
# sample_1284  5.726562  5.902344  5.917969
# sample_1285  5.984375  6.222656  6.222656
# sample_1286  5.488281  5.710938  6.019531
# sample_1287  5.867188  6.203125  6.371094
# sample_1288  4.148438  4.273438  4.125000
#
# [194 rows x 1612 columns]

# %% [markdown]
# Get basic dataset info

# %%
# getting class number
class_num = len(train_data['y'].unique())
print("Number of classes: %s"%class_num)
# getting samples number
sample_num_train = len(train_data.index)
sample_num_test = len(test_data.index)
print("Training set size: %s \nTest set size: %s"%(sample_num_train,sample_num_test))
# getting features number
features_num = len(train_data.columns) - 1 # -1 couse one column is y
print("Number of features: %s"%features_num)
# Out:
# Number of classes: 2
# Training set size: 1095
# Test set size: 194
# Number of features: 1612

# %%
# Separate y column from all others
def get_y(imput_df, y_column = 'y'):
    y_vector = np.array(imput_df[y_column])
    x_frame = imput_df.drop(y_column, inplace=False, axis=1)
    return x_frame, y_vector

# %%
train_x_df, train_y = get_y(train_data)

# %% [markdown]
# #### Data preparation.
# 1. At first we drop feature columns with more then 30% missing data points.
# 2. Then we will fix missing and inf data points. For this we will use impute missing values with mean of this feature column.
# 3. Then we will scale data in each column for it to be in [0,1] boundaries.

# %%
# Drop feature columns with not enough data
drop_column_rate = 0.3

def drop_columns(input_df, drop_column_rate):
    dropped_columns = []
    sample_num = len(input_df.index)
    # get number of samples for column to be dropped
    sample_limit = int(sample_num * drop_column_rate)
    
    for column in input_df.columns:
        input_df.loc[input_df[column] >= 1E308, column] = np.nan # Fill all the infinities 
        if input_df[column].isnull().sum() > sample_limit: # check for number of empty data points in a feature column
            dropped_columns.append(column)

    cleaned_df = input_df.drop(dropped_columns, inplace=False, axis=1)
    
    return cleaned_df, dropped_columns

# %%
cl_train_x, dropped_columns = drop_columns(train_x_df, drop_column_rate)
cleaned_features = len(cl_train_x.columns) - 1 # -1 couse one column is y
print("Number of features after cleanup: %s"%cleaned_features)
# Out:
# Number of features after cleanup: 1449

# %%
# Now we will get numpy array of train
train_x = cl_train_x.values

# %%
train_x.shape
# Out:
# (1095, 1450)

# %%
nancount = 0
for i in range(train_x.shape[0]):
    row = train_x[i]
    for j in range(train_x.shape[1]):
        if np.isnan(row[j]):
            nancount += 1
print("Number of nans is %i"%nancount)
# Out:
# Number of nans is 6676

# %%
# Continue with imputing data

from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imputed_train_x = imp.fit_transform(train_x)

# %%
# Lets check if all the nans are gone
nancount = 0
for i in range(imputed_train_x.shape[0]):
    row = imputed_train_x[i]
    for j in range(imputed_train_x.shape[1]):
        if np.isnan(row[j]):
            nancount += 1
print("Number of nans is %i"%nancount)
# Out:
# Number of nans is 0

# %% [markdown]
# Done with imputing, lets scale our data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaled_train_x = scaler.fit_transform(imputed_train_x)

# %% [markdown]
# #### Neural net training

# %%
epochs = 100
val_split = 0.2 # We cant get too big of a validation with just 1000 training examples, so 20% will do
patience = 30 # epochs to wait for early stopping
dropout_rate = 0.5

# %%
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout
from keras.regularizers import l2
from keras.callbacks import EarlyStopping, ModelCheckpoint
#create model
model = Sequential()

#get number of columns in training data
n_cols = scaled_train_x.shape[1]

#add model layers
model.add(Dense(512, activation='relu', input_shape=(n_cols,)))
model.add(Dense(256, activation='relu'))
#model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='mse', metrics = ['accuracy'])

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=patience)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

save_history = model.fit(scaled_train_x, train_y, epochs=epochs, batch_size = 64, verbose=1, validation_split=val_split, callbacks=[mc, es])

model = load_model('best_model.h5')
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 876 samples, validate on 219 samples
# Epoch 1/100
# 876/876 [==============================] - 1s 1ms/step - loss: 0.2336 - acc: 0.6142 - val_loss: 0.1774 - val_acc: 0.7717
#
# Epoch 00001: val_acc improved from -inf to 0.77169, saving model to best_model.h5
# Epoch 2/100
# 876/876 [==============================] - 0s 380us/step - loss: 0.1972 - acc: 0.6998 - val_loss: 0.1584 - val_acc: 0.7671
#
# Epoch 00002: val_acc did not improve from 0.77169
# Epoch 3/100
# 876/876 [==============================] - 0s 452us/step - loss: 0.1742 - acc: 0.7432 - val_loss: 0.1606 - val_acc: 0.7534
#
# Epoch 00003: val_acc did not improve from 0.77169
# Epoch 4/100
# 876/876 [==============================] - 1s 606us/step - loss: 0.1608 - acc: 0.7546 - val_loss: 0.1927 - val_acc: 0.7443
#
# Epoch 00004: val_acc did not improve from 0.77169
# Epoch 5/100
# 876/876 [==============================] - 1s 661us/step - loss: 0.1670 - acc: 0.7591 - val_loss: 0.2644 - val_acc: 0.5982
#
# Epoch 00005: val_acc did not improve from 0.77169
# Epoch 6/100
# 876/876 [==============================] - 0s 357us/step - loss: 0.1551 - acc: 0.7660 - val_loss: 0.2389 - val_acc: 0.6530
#
# Epoch 00006: val_acc did not improve from 0.77169
# Epoch 7/100
# 876/876 [==============================] - 1s 611us/step - loss: 0.1750 - acc: 0.7329 - val_loss: 0.3276 - val_acc: 0.4429
#
# Epoch 00007: val_acc did not improve from 0.77169
# Epoch 8/100
# 876/876 [==============================] - 0s 372us/step - loss: 0.1758 - acc: 0.7363 - val_loss: 0.1696 - val_acc: 0.7489
#
# Epoch 00008: val_acc did not improve from 0.77169
# Epoch 9/100
# 876/876 [==============================] - 0s 361us/step - loss: 0.1509 - acc: 0.7831 - val_loss: 0.2138 - val_acc: 0.6849
#
# Epoch 00009: val_acc did not improve from 0.77169
# Epoch 10/100
# 876/876 [==============================] - 0s 558us/step - loss: 0.1453 - acc: 0.7945 - val_loss: 0.1674 - val_acc: 0.7443
#
# Epoch 00010: val_acc did not improve from 0.77169
# Epoch 11/100
# 876/876 [==============================] - 0s 421us/step - loss: 0.1513 - acc: 0.7751 - val_loss: 0.1704 - val_acc: 0.7580
#
# Epoch 00011: val_acc did not improve from 0.77169
# Epoch 12/100
# 876/876 [==============================] - 1s 856us/step - loss: 0.1394 - acc: 0.8014 - val_loss: 0.2207 - val_acc: 0.6621
#
# Epoch 00012: val_acc did not improve from 0.77169
# Epoch 13/100
# 876/876 [==============================] - 0s 432us/step - loss: 0.1306 - acc: 0.8116 - val_loss: 0.1485 - val_acc: 0.7945
#
# Epoch 00013: val_acc improved from 0.77169 to 0.79452, saving model to best_model.h5
# Epoch 14/100
# 876/876 [==============================] - 1s 823us/step - loss: 0.1510 - acc: 0.7751 - val_loss: 0.2368 - val_acc: 0.6393
#
# Epoch 00014: val_acc did not improve from 0.79452
# Epoch 15/100
# 876/876 [==============================] - 1s 863us/step - loss: 0.1435 - acc: 0.8002 - val_loss: 0.1609 - val_acc: 0.7671
#
# Epoch 00015: val_acc did not improve from 0.79452
# Epoch 16/100
# 876/876 [==============================] - 1s 1ms/step - loss: 0.1301 - acc: 0.8094 - val_loss: 0.2495 - val_acc: 0.6301
#
# Epoch 00016: val_acc did not improve from 0.79452
# Epoch 17/100
# 876/876 [==============================] - 2s 2ms/step - loss: 0.1381 - acc: 0.8037 - val_loss: 0.1444 - val_acc: 0.7991
#
# Epoch 00017: val_acc improved from 0.79452 to 0.79909, saving model to best_model.h5
# Epoch 18/100
# 876/876 [==============================] - 1s 876us/step - loss: 0.1336 - acc: 0.8037 - val_loss: 0.1810 - val_acc: 0.7489
#
# Epoch 00018: val_acc did not improve from 0.79909
# Epoch 19/100
# 876/876 [==============================] - 0s 479us/step - loss: 0.1286 - acc: 0.8174 - val_loss: 0.1497 - val_acc: 0.7991
#
# Epoch 00019: val_acc did not improve from 0.79909
# Epoch 20/100
# 876/876 [==============================] - 0s 542us/step - loss: 0.1229 - acc: 0.8276 - val_loss: 0.2751 - val_acc: 0.5982
#
# Epoch 00020: val_acc did not improve from 0.79909
# Epoch 21/100
# 876/876 [==============================] - 1s 607us/step - loss: 0.1253 - acc: 0.8231 - val_loss: 0.1708 - val_acc: 0.7626
#
# Epoch 00021: val_acc did not improve from 0.79909
# Epoch 22/100
# 876/876 [==============================] - 1s 1ms/step - loss: 0.1169 - acc: 0.8368 - val_loss: 0.1692 - val_acc: 0.7808
#
# Epoch 00022: val_acc did not improve from 0.79909
# Epoch 23/100
# 876/876 [==============================] - 1s 922us/step - loss: 0.1156 - acc: 0.8402 - val_loss: 0.1763 - val_acc: 0.7626
#
# Epoch 00023: val_acc did not improve from 0.79909
# Epoch 24/100
# 876/876 [==============================] - 0s 486us/step - loss: 0.1169 - acc: 0.8459 - val_loss: 0.2002 - val_acc: 0.7260
#
# Epoch 00024: val_acc did not improve from 0.79909
# Epoch 25/100
# 876/876 [==============================] - 1s 700us/step - loss: 0.1152 - acc: 0.8413 - val_loss: 0.2176 - val_acc: 0.6758
#
# Epoch 00025: val_acc did not improve from 0.79909
# Epoch 26/100
# 876/876 [==============================] - 0s 467us/step - loss: 0.1171 - acc: 0.8253 - val_loss: 0.1506 - val_acc: 0.7900
#
# Epoch 00026: val_acc did not improve from 0.79909
# Epoch 27/100
# 876/876 [==============================] - 1s 694us/step - loss: 0.1183 - acc: 0.8527 - val_loss: 0.1435 - val_acc: 0.7991
#
# Epoch 00027: val_acc did not improve from 0.79909
# Epoch 28/100
# 876/876 [==============================] - 0s 478us/step - loss: 0.1350 - acc: 0.8059 - val_loss: 0.1722 - val_acc: 0.7717
#
# Epoch 00028: val_acc did not improve from 0.79909
# Epoch 29/100
# 876/876 [==============================] - 1s 929us/step - loss: 0.1218 - acc: 0.8402 - val_loss: 0.2018 - val_acc: 0.7215
#
# Epoch 00029: val_acc did not improve from 0.79909
# Epoch 30/100
# 876/876 [==============================] - 1s 693us/step - loss: 0.1189 - acc: 0.8345 - val_loss: 0.1436 - val_acc: 0.7854
#
# Epoch 00030: val_acc did not improve from 0.79909
# Epoch 31/100
# 876/876 [==============================] - 1s 918us/step - loss: 0.1334 - acc: 0.8128 - val_loss: 0.1411 - val_acc: 0.8128
#
# Epoch 00031: val_acc improved from 0.79909 to 0.81279, saving model to best_model.h5
# Epoch 32/100
# 876/876 [==============================] - 0s 473us/step - loss: 0.1195 - acc: 0.8436 - val_loss: 0.1512 - val_acc: 0.7808
#
# Epoch 00032: val_acc did not improve from 0.81279
# Epoch 33/100
# 876/876 [==============================] - 1s 572us/step - loss: 0.1144 - acc: 0.8470 - val_loss: 0.1927 - val_acc: 0.7443
#
# Epoch 00033: val_acc did not improve from 0.81279
# Epoch 34/100
# 876/876 [==============================] - 1s 782us/step - loss: 0.1135 - acc: 0.8425 - val_loss: 0.1687 - val_acc: 0.7854
#
# Epoch 00034: val_acc did not improve from 0.81279
# Epoch 35/100
# 876/876 [==============================] - 1s 720us/step - loss: 0.1104 - acc: 0.8447 - val_loss: 0.1545 - val_acc: 0.7945
#
# Epoch 00035: val_acc did not improve from 0.81279
# Epoch 36/100
# 876/876 [==============================] - 0s 465us/step - loss: 0.1137 - acc: 0.8402 - val_loss: 0.2771 - val_acc: 0.6119
#
# Epoch 00036: val_acc did not improve from 0.81279
# Epoch 37/100
# 876/876 [==============================] - 1s 635us/step - loss: 0.1157 - acc: 0.8379 - val_loss: 0.1438 - val_acc: 0.8082
#
# Epoch 00037: val_acc did not improve from 0.81279
# Epoch 38/100
# 876/876 [==============================] - 1s 608us/step - loss: 0.1140 - acc: 0.8470 - val_loss: 0.1844 - val_acc: 0.7580
#
# Epoch 00038: val_acc did not improve from 0.81279
# Epoch 39/100
# 876/876 [==============================] - 1s 674us/step - loss: 0.1155 - acc: 0.8413 - val_loss: 0.1992 - val_acc: 0.7397
#
# Epoch 00039: val_acc did not improve from 0.81279
# Epoch 40/100
# 876/876 [==============================] - 1s 725us/step - loss: 0.1062 - acc: 0.8573 - val_loss: 0.1414 - val_acc: 0.8128
#
# Epoch 00040: val_acc improved from 0.81279 to 0.81279, saving model to best_model.h5
# Epoch 41/100
# 876/876 [==============================] - 1s 693us/step - loss: 0.1067 - acc: 0.8527 - val_loss: 0.1455 - val_acc: 0.8037
#
# Epoch 00041: val_acc did not improve from 0.81279
# Epoch 42/100
# 876/876 [==============================] - 1s 674us/step - loss: 0.1106 - acc: 0.8436 - val_loss: 0.1478 - val_acc: 0.7763
#
# Epoch 00042: val_acc did not improve from 0.81279
# Epoch 43/100
# 876/876 [==============================] - 0s 360us/step - loss: 0.0995 - acc: 0.8699 - val_loss: 0.2160 - val_acc: 0.6986
#
# Epoch 00043: val_acc did not improve from 0.81279
# Epoch 44/100
# 876/876 [==============================] - 0s 372us/step - loss: 0.0954 - acc: 0.8801 - val_loss: 0.1552 - val_acc: 0.7991
#
# Epoch 00044: val_acc did not improve from 0.81279
# Epoch 45/100
# 876/876 [==============================] - 0s 430us/step - loss: 0.0971 - acc: 0.8779 - val_loss: 0.1652 - val_acc: 0.7854
#
# Epoch 00045: val_acc did not improve from 0.81279
# Epoch 46/100
# 876/876 [==============================] - 0s 398us/step - loss: 0.0953 - acc: 0.8824 - val_loss: 0.1485 - val_acc: 0.8037
#
# Epoch 00046: val_acc did not improve from 0.81279
# Epoch 47/100
# 876/876 [==============================] - 1s 596us/step - loss: 0.0954 - acc: 0.8744 - val_loss: 0.1774 - val_acc: 0.7626
#
# Epoch 00047: val_acc did not improve from 0.81279
# Epoch 48/100
# 876/876 [==============================] - 1s 800us/step - loss: 0.0961 - acc: 0.8767 - val_loss: 0.2626 - val_acc: 0.6210
#
# Epoch 00048: val_acc did not improve from 0.81279
# Epoch 49/100
# 876/876 [==============================] - 0s 554us/step - loss: 0.0922 - acc: 0.8836 - val_loss: 0.1707 - val_acc: 0.7854
#
# Epoch 00049: val_acc did not improve from 0.81279
# Epoch 50/100
# 876/876 [==============================] - 1s 774us/step - loss: 0.0899 - acc: 0.8767 - val_loss: 0.2176 - val_acc: 0.6941
#
# Epoch 00050: val_acc did not improve from 0.81279
# Epoch 51/100
# 876/876 [==============================] - 0s 473us/step - loss: 0.0926 - acc: 0.8779 - val_loss: 0.1825 - val_acc: 0.7443
#
# Epoch 00051: val_acc did not improve from 0.81279
# Epoch 52/100
# 876/876 [==============================] - 1s 860us/step - loss: 0.0858 - acc: 0.8938 - val_loss: 0.1881 - val_acc: 0.7443
#
# Epoch 00052: val_acc did not improve from 0.81279
# Epoch 53/100
# 876/876 [==============================] - 0s 428us/step - loss: 0.0937 - acc: 0.8744 - val_loss: 0.2076 - val_acc: 0.6895
#
# Epoch 00053: val_acc did not improve from 0.81279
# Epoch 54/100
# 876/876 [==============================] - 1s 578us/step - loss: 0.1271 - acc: 0.8139 - val_loss: 0.2450 - val_acc: 0.6256
#
# Epoch 00054: val_acc did not improve from 0.81279
# Epoch 55/100
# 876/876 [==============================] - 0s 492us/step - loss: 0.0959 - acc: 0.8710 - val_loss: 0.1778 - val_acc: 0.7397
#
# Epoch 00055: val_acc did not improve from 0.81279
# Epoch 56/100
# 876/876 [==============================] - 0s 475us/step - loss: 0.0876 - acc: 0.8881 - val_loss: 0.2003 - val_acc: 0.7215
#
# Epoch 00056: val_acc did not improve from 0.81279
# Epoch 57/100
# 876/876 [==============================] - 0s 490us/step - loss: 0.0962 - acc: 0.8619 - val_loss: 0.1570 - val_acc: 0.8037
#
# Epoch 00057: val_acc did not improve from 0.81279
# Epoch 58/100
# 876/876 [==============================] - 0s 557us/step - loss: 0.0990 - acc: 0.8756 - val_loss: 0.1763 - val_acc: 0.7717
#
# Epoch 00058: val_acc did not improve from 0.81279
# Epoch 59/100
# 876/876 [==============================] - 1s 747us/step - loss: 0.0873 - acc: 0.8779 - val_loss: 0.1678 - val_acc: 0.7808
#
# Epoch 00059: val_acc did not improve from 0.81279
# Epoch 60/100
# 876/876 [==============================] - 0s 396us/step - loss: 0.0958 - acc: 0.8687 - val_loss: 0.1727 - val_acc: 0.7626
#
# Epoch 00060: val_acc did not improve from 0.81279
# Epoch 61/100
# 876/876 [==============================] - 1s 616us/step - loss: 0.0827 - acc: 0.8984 - val_loss: 0.1514 - val_acc: 0.8082
#
# Epoch 00061: val_acc did not improve from 0.81279
# Epoch 00061: early stopping

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

fig = plt.figure()
graph1 = plt.plot(save_history.history['acc'])
plt.title("Train accuracy")
plt.show()

fig = plt.figure()
graph1 = plt.plot(save_history.history['val_acc'])
plt.title("Validation accuracy")
plt.show()

fig = plt.figure()
graph1 = plt.plot(save_history.history['loss'])
plt.title("Train loss")
plt.show()

fig = plt.figure()
graph1 = plt.plot(save_history.history['val_loss'])
plt.title("Validation loss")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ##### Test data preprocess

# %%
cleaned_test = test_data.drop(dropped_columns, inplace=False, axis=1) # drop same columns from test set
for column in cleaned_test.columns:
    cleaned_test.loc[cleaned_test[column] >= 1E308, column] = np.nan # Fill all the infinities 
test_x = cleaned_test.values # Turn into numpy array
imputed_test = imp.transform(test_x) # Inpute with trained inputer
scaled_test = scaler.transform(imputed_test) # Scale with trained scaler

# %%
test_y = model.predict(scaled_test)

# %%
y_list = test_y.reshape(len(test_y)).tolist()

test_df = pd.DataFrame({"sample_id": list(test_data.index), "y": y_list})

# %%
# Save submission
test_df.to_csv("submission.csv",sep = ',', index = False)
